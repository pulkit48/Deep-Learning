# %% [markdown]
# <a href="https://colab.research.google.com/github/pulkit48/Deep-Learning/blob/main/Methods_to_improve_performance_of_NN/03_Data_Scaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Social_Network_Ads.csv')

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
import seaborn as sns

# %%
sns.scatterplot(x=df.iloc[:,0],y=df.iloc[:,1])
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(128,activation='relu',input_dim=2))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               384
#
#  dense_1 (Dense)             (None, 1)                 129
#
# ...
# Total params: 513 (2.00 KB)
# Trainable params: 513 (2.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 31ms/step - loss: 127.0467 - accuracy: 0.5031 - val_loss: 186.7130 - val_accuracy: 0.4000
# Epoch 2/100
# 10/10 [==============================] - 0s 10ms/step - loss: 173.1951 - accuracy: 0.4656 - val_loss: 82.5919 - val_accuracy: 0.4000
# Epoch 3/100
# 10/10 [==============================] - 0s 15ms/step - loss: 112.5829 - accuracy: 0.5125 - val_loss: 32.4846 - val_accuracy: 0.4000
# Epoch 4/100
# 10/10 [==============================] - 0s 13ms/step - loss: 81.1978 - accuracy: 0.4406 - val_loss: 1.5298 - val_accuracy: 0.4000
# Epoch 5/100
# 10/10 [==============================] - 0s 16ms/step - loss: 138.4822 - accuracy: 0.5219 - val_loss: 199.0769 - val_accuracy: 0.4000
# Epoch 6/100
# 10/10 [==============================] - 0s 10ms/step - loss: 108.0087 - accuracy: 0.4844 - val_loss: 17.5515 - val_accuracy: 0.6000
# Epoch 7/100
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['val_accuracy'])

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.fit_transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 0.88928823, -0.65924556],
#        [-0.17254846,  0.87392651],
#        [-1.04132394, -0.36440478],
#        [ 0.98581884,  0.6085698 ],
#        [-0.94479333,  0.57908572],
#        [ 0.40663519,  0.01888824],
#        [ 0.98581884,  2.11225779],
#        [ 0.31010458, -0.30543662],
#        [ 1.7580637 , -0.27595254],
#        [-0.17254846,  2.20071003],
#        [ 1.7580637 ,  1.0213469 ],
#        [-1.33091576, -1.48479975],
#        [ 2.04765553,  0.54960165],
#        [ 1.27541066,  1.90586924],
#        [-1.13785454,  0.31372902],
#        [-0.36560968, -0.77718187],
#        [-1.71703819,  0.49063349],
#        [-0.5586709 , -1.51428383],
#        [ 0.31010458, -0.71821372],
#        [ 0.02051275, -0.57079333],
#        [ 0.02051275,  0.04837232],
#        [-0.07601785, -0.51182517],
#        [-0.6552015 , -1.51428383],
#        [ 0.02051275,  0.31372902],
#        [ 0.31010458,  0.07785639],
#        [-0.46214029, -1.13099081],
#        [-0.75173211, -1.54376791],
# ...

# %%
sns.scatterplot(x=df.iloc[:,0],y=df.iloc[:,1])
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
model = Sequential()

model.add(Dense(128,activation='relu',input_dim=2))
model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

history = model.fit(X_train_scaled,y_train,validation_data=(X_test_scaled,y_test),epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 92ms/step - loss: 0.7155 - accuracy: 0.4281 - val_loss: 0.6792 - val_accuracy: 0.6625
# Epoch 2/100
# 10/10 [==============================] - 0s 16ms/step - loss: 0.6504 - accuracy: 0.7656 - val_loss: 0.6193 - val_accuracy: 0.7500
# Epoch 3/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5963 - accuracy: 0.7969 - val_loss: 0.5672 - val_accuracy: 0.8000
# Epoch 4/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5497 - accuracy: 0.8156 - val_loss: 0.5231 - val_accuracy: 0.7875
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5085 - accuracy: 0.8250 - val_loss: 0.4868 - val_accuracy: 0.8000
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4744 - accuracy: 0.8375 - val_loss: 0.4550 - val_accuracy: 0.8125
# Epoch 7/100
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['val_accuracy'])
